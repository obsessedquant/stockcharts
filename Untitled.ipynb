# %%
with open('tidy_test.txt') as f:
    contents = f.read()
    print(contents)
# Out:
# <div id="symbolgrid">
# 	<table class="symbolgrid">
# 		<thead>
# 			<tr>
# 				<th>chart</th>
# 				<th>visible</th>
# 				<th class="sort-descending">tail</th>
# 				<th>symbol</th>
# 				<th>name</th>
# 				<th>sector</th>
# 				<th>industry</th>
# 				<th>price</th>
# 				<th>%chg</th>
# 			</tr>
# 		</thead>
# 		<tbody>
# 			<tr class="row green">
# 				<td align="center" class="chart">
# 					<a href="/h-sc/ui?s=$DJUSFC">
# 						<img src="/freecharts/rrg/candle.gif" alt="Candlesticks Icon"/>
# 					</td>
# 					<td align="center" class="visible">
# 						<input type="checkbox" checked="checked" aria-label="Deselect to remove symbol from chart"/>
# 						<td align="left" class="tail">
# 							<img src="/freecharts/rrg/greenbar.png" width="25" height="10" alt="bar icon"/>
# 							<td align="right" class="symbol">$DJUSFC</td>
# 							<td align="right" class="name">Dow Jones US Fixed Line Telecommunications Index</td>
# 							<td align="right" class="sector"/>
# ...

# %%
for char in contents:
    
    if char = 't':
        tr_class = 't'
    
    print(char)
# Out:
# <
# d
# i
# v
#
# i
# d
# =
# "
# s
# y
# m
# b
# o
# l
# g
# r
# i
# d
# "
# >
#
#
#
# <
# t
# a
# b
# l
# e
#
# c
# l
# a
# s
# s
# =
# "
# s
# y
# m
# b
# o
# l
# g
# r
# i
# d
# "
# >
#
#
#
#
# <
# t
# h
# e
# a
# d
# >
#
#
#
#
#
# <
# t
# r
# >
#
#
#
#
#
#
# <
# t
# h
# >
# c
# h
# a
# r
# t
# <
# /
# t
# h
# >
#
#
#
#
#
#
# <
# t
# h
# >
# v
# i
# s
# i
# b
# l
# e
# <
# /
# t
# h
# >
#
#
#
#
#
#
# <
# t
# h
#
# c
# l
# a
# s
# s
# =
# "
# s
# o
# r
# t
# -
# d
# e
# s
# c
# e
# n
# d
# i
# n
# g
# "
# >
# t
# a
# i
# l
# <
# /
# t
# h
# >
#
#
#
#
#
#
# <
# t
# h
# >
# s
# y
# m
# b
# o
# l
# <
# /
# t
# h
# >
#
#
#
#
#
#
# <
# t
# h
# >
# n
# a
# m
# e
# <
# /
# t
# h
# >
#
#
#
#
#
#
# <
# t
# h
# >
# s
# e
# c
# t
# o
# r
# <
# /
# t
# h
# >
#
#
#
#
#
#
# <
# t
# h
# >
# i
# n
# d
# u
# s
# t
# r
# y
# <
# /
# t
# h
# >
#
#
#
#
#
#
# <
# t
# h
# >
# p
# r
# i
# c
# e
# <
# /
# t
# h
# >
#
#
#
#
#
#
# <
# t
# h
# >
# %
# c
# h
# g
# <
# /
# t
# h
# >
#
#
#
#
#
# <
# /
# t
# r
# ...
